# %% [markdown]
# ## Initial Equilibrium in Adamopoulos et al. (2024, *QJE*)
#
# This script:
# - Sets up the baseline model configuration.
# - Runs the calibration \& estimation via particle swarm (outer loop) with equilibrium solving (inner loop).
# - Displays calibrated parameters, endogenous prices, and model vs. data moments.

# %%
import numpy as np
import time
from module_eqm import (
    get_data_moments,
    set_exogenous_params,
    assign_parameter_value,
    prepare_individual_blocks,
    solve_equilibrium,
    compute_all_moments,
    calibration_objective,
)
